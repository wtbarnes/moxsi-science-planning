# %%
from astropy.visualization import ImageNormalize, LogStretch

from mocksipipeline.util import build_moxsi_collection
from mocksipipeline.visualization import plot_detector_image

# %%
col = build_moxsi_collection('../../../../codes/mocksipipeline/pipeline/results/cdr/rfa/ar_1h_coronal/detector_images/')

# %%
fig = plot_detector_image(
    col,
    add_colorbar=False,
    label_components=True,
    hide_tick_and_axes_labels=True,
    label_north=True,
    figsize=(10,10),
)
fig.savefig('agu-tv-moxsi-active-region-labeled.pdf', bbox_inches='tight')
fig.savefig('agu-tv-moxsi-active-region-labeled.png', dpi=500, bbox_inches='tight')
fig.savefig('agu-tv-moxsi-active-region-labeled.jpg', dpi=500, bbox_inches='tight')
